# %%
import openmeteo_requests
import requests_cache
from retry_requests import retry
from datetime import datetime

# %%
# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = 3600)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# %%
# Parameters
url = "https://api.open-meteo.com/v1/forecast"
params = {
	"latitude": 52.2298,
	"longitude": 21.0118,
	"current": ["temperature_2m", "apparent_temperature", "wind_speed_10m"],
	"timezone": "Europe/Berlin",
}
responses = openmeteo.weather_api(url, params = params)

# %%
# Process current data
response = responses[0]
current = response.Current()
current_time = datetime.fromtimestamp(current.Time())
current_temperature_2m = current.Variables(0).Value()
current_apparent_temperature = current.Variables(1).Value()
current_wind_speed_10m = current.Variables(2).Value()

# %%
# Print current data
print(f"Current time: {current_time}")
print(f"Current temperature_2m: {current_temperature_2m:.1f} °C")
print(f"Current apparent_temperature: {current_apparent_temperature:.1f} °C")
print(f"Current wind_speed_10m: {current_wind_speed_10m:.1f} km/h")
# Out:
# Current time: 2026-06-23 15:15:00
# Current temperature_2m: 24.4 °C
# Current apparent_temperature: 21.7 °C
# Current wind_speed_10m: 13.3 km/h

# %%
from weather_api import get_current_weather

pogoda_teraz = get_current_weather()
print(pogoda_teraz)
# Out:
# {'timestamp': '2026-06-30 15:30:00', 'temperature': 30.5, 'apparent_temperature': 32.4, 'wind_speed': 9.0}

# %%
from weather_api import get_current_weather
from db import init_db, save_weather_to_db

init_db()

pogoda_teraz = get_current_weather()
print(pogoda_teraz)

save_weather_to_db(pogoda_teraz)
# Out:
# {'timestamp': '2026-06-25 16:30:00', 'temperature': 30.3, 'apparent_temperature': 30.1, 'wind_speed': 11.2}
# Weather data successfully saved to the database.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("pogoda.db")

df = pd.read_sql_query("SELECT * FROM weather_logs", conn)

conn.close()

df
# Out:
#    id            timestamp  temperature  apparent_temperature  wind_speed
# 0   1  2026-06-25 16:30:00         30.3                  30.1        11.2
# 1   2  2026-06-25 16:30:00         30.3                  30.1        11.2
# 2   3  2026-06-25 16:30:00         30.3                  30.1        11.2
# 3   4  2026-06-25 16:30:00         30.3                  30.1        11.2
